# %%
'''1. Write a Python program to add two numbers.


2. Write a Python program to find the remainder when a number is divided by z.


3. Check the type of variable assigned using input() function.


4. Use the comparison operator to find out whether a given variable a is greater than b or not. Take a = 34 and b = 80.


5. Write a Python program to find the average of two numbers entered by the user.


6. Write a Python program to calculate the square of a number entered by the user.'''

a=int(input("enter 1st no."))
b=int(input("enter 2st no."))
print("the sum is:",a+b)
# Out:
# the sum is: 29

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2st no."))
print("the remender is:",a%b)
# Out:
# the remender is: 4

# %%
a=input("enter a")
print(type(a))
# Out:
# <class 'str'>

# %%
a = 34
b = 80
print("a is greater then b:",a>b)
# Out:
# a is greater then b: False

# %%
a=int(input("enter 1st no."))
b=int(input("enter 2st no."))
print("the avg is:",(a+b)/2)
# Out:
# the avg is: 3.0

# %%
a=int(input("enter 1st no."))

print("the square is:",a*a)
# Out:
# the square is: 9

# %%
#string
#slicing ( immutable )
name="kartikeya"
print(name)
# Out:
# kartikeya

# %%
print(name[3])
print(name[0:3])
print(name[-4:-1])
print(name[-1:-10:-1])
print(name[0:19:2])
# Out:
# t
# kar
# key
# ayekitrak
# kriea

# %%
#functions in string
s="     i am learning python     "
print(name)
print(len(name))
print(name.startswith("Kart"))
print(name.endswith("ya"))
print(name.capitalize())# is only capitalize th first letter
print(name.title())
print(s.title())
print(name.swapcase())
print(name.strip())
print(s.strip())# it removes the space from the both the sides of string

print(s.lstrip("i am"))

print(name.rstrip("a"))
print(name)
print(name.lstrip("p"))
# Out:
# kartikeya
# 9
# False
# True
# Kartikeya
# Kartikeya
#      I Am Learning Python
# KARTIKEYA
# kartikeya
# i am learning python
# learning python
# kartikey
# kartikeya
# kartikeya

# %%
#escape character \t,\n,\',\\
s="\\ right now\ni am\tlearning python on \"vs code\"\\"
print(s)
# Out:
# \ right now
# i am	learning python on "vs code"\

# %%
letter='''dear <|name|>
 you are selected!
   <|date|>'''
print(letter.replace("<|name|>","kartikeya").replace("<|date|>","27 june 2026"))
# Out:
# dear kartikeya
#  you are selected!
#    27 june 2026

# %%
print(f"good afternoon {name}")
# Out:
# good afternoon kartikeya
