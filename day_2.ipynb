# %%
#Dict- dictionary
#built in data structure that keeps keys: alue pairs
#keys always unique

# %%
dict()
# Out:
# {}

# %%
student={'name':'rahul','age':11,'city':'delhi'}
student
# Out:
# {'name': 'rahul', 'age': 11, 'city': 'delhi'}

# %%
d1=dict(name=' kartikeya',age=19,city='udaipur')
d1
# Out:
# {'name': ' kartikeya', 'age': 19, 'city': 'udaipur'}

# %%
type(d1)
# Out:
# dict

# %%
#access the element of dictionary
print(student['age'])
print(d1['city'])
# Out:
# 11
# udaipur

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
d1.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
d1.values()
# Out:
# dict_values([' kartikeya', 19, 'udaipur'])

# %%
student.get("age")
# Out:
# 11

# %%
#update value
student['city']='bombay'
student
# Out:
# {'name': 'rahul', 'age': 11, 'city': 'bombay'}

# %%
#how to add anything
student['sex']='male'
student
# Out:
# {'name': 'rahul', 'age': 11, 'city': 'bombay', 'sex': 'male'}

# %%
#how to remove-pop()
student['city']='bombay'
student.pop(('city','age'))
student
# Out:
# {'name': 'rahul', 'sex': 'male', 'city': 'bombay'}

# %%
student.popitem()
# Out:
# ('city', 'bombay')

# %%
student
# Out:
# {'name': 'rahul', 'sex': 'male'}

# %%
del student['name']

# %%
student
# Out:
# {'sex': 'male'}

# %%
#remove all the elements from the dict
student.clear()

# %%
student
# Out:
# {}

# %%
d1.clear()
d1
# Out:
# {}

# %%
d1=dict(name='kartikeya',age=19,city='dholakpur')

# %%
d1
# Out:
# {'name': 'kartikeya', 'age': 19, 'city': 'dholakpur'}

# %%
d1.items()
# Out:
# dict_items([('name', 'kartikeya'), ('age', 19), ('city', 'dholakpur')])

# %%
#key print using loop
for i in d1.keys():
    print(i)
# Out:
# name
# age
# city

# %%
for j in d1.values():
    print(j)
# Out:
# kartikeya
# 19
# dholakpur

# %%
for i,j in d1.items():
    print(i,j)
# Out:
# name kartikeya
# age 19
# city dholakpur

# %%
#nested dict
students={'s1':{'name':'kartik','age':20,'sex':"male"},'s2':{'name':'kartikeya','age':19,'sex':'male'}}
students
# Out:
# {'s1': {'name': 'kartik', 'age': 20, 'sex': 'male'},
#  's2': {'name': 'kartikeya', 'age': 19, 'sex': 'male'}}

# %%
students['s1']['name']
# Out:
# 'kartik'

# %%
students['s1']['name']='raghav'

# %%
students
# Out:
# {'s1': {'name': 'raghav', 'age': 20, 'sex': 'male'},
#  's2': {'name': 'kartikeya', 'age': 19, 'sex': 'male'}}

# %%
students['s1']['grade']='S'

# %%
students
# Out:
# {'s1': {'name': 'raghav', 'age': 20, 'sex': 'male', 'grade': 'S'},
#  's2': {'name': 'kartikeya', 'age': 19, 'sex': 'male'}}

# %%
if 's1'in students:
    print("true")
# Out:
# true

# %%
#dict comphrehension3
sqrt={x:x*x for x in range(10)}
sqrt
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
del students['s1']['age']

# %%
students
# Out:
# {'s1': {'name': 'raghav', 'sex': 'male', 'grade': 'S'},
#  's2': {'name': 'kartikeya', 'age': 19, 'sex': 'male'}}

# %%
del students['s1']

# %%
students
# Out:
# {'s2': {'name': 'kartikeya', 'age': 19, 'sex': 'male'}}

# %%
students['s2'].pop('sex')
# Out:
# 'male'

# %%
students
# Out:
# {'s2': {'name': 'kartikeya', 'age': 19}}

# %%
students.pop('s2')
# Out:
# {'name': 'kartikeya', 'age': 19}

# %%
students
# Out:
# {}

# %%
students={'s1':{'name':'kartik','age':20,'city':'dubai'},'s2':{'name':'raghav','age':10,'city':'bombay'},'s3':{'name':'kartikeya','age':22,'city':'delhi'}}

# %%
students
# Out:
# {'s1': {'name': 'kartik', 'age': 20, 'city': 'dubai'},
#  's2': {'name': 'raghav', 'age': 10, 'city': 'bombay'},
#  's3': {'name': 'kartikeya', 'age': 22, 'city': 'delhi'}}

# %%
students={
    key:value
    for key,value in students.items()
    if value['age']<=21
}

# %%
students
# Out:
# {'s1': {'name': 'kartik', 'age': 20, 'city': 'dubai'},
#  's2': {'name': 'raghav', 'age': 10, 'city': 'bombay'}}

# %%
d={'a':1,'b':2}
d['c']=3
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d={'a':1,'b':2}
print(d.get('c'))
print(d.get('a'))
# Out:
# None
# 1

# %%
d1={'x':1,'y':2}
d2=d1.copy()
d3=d1
d2['z']=3
d3['x']=50
print(d1)
print(d2)
print(d3)
# Out:
# {'x': 50, 'y': 2}
# {'x': 1, 'y': 2, 'z': 3}
# {'x': 50, 'y': 2}

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d={'a':1,'b':2,'c':3,'e':4}
for k, v in list(d.items()):
    if v%2==0:
        d.pop(k)
print(d)
# Out:
# {'a': 1, 'c': 3}

# %%
data={'emp1':{'name':'ck','salary':10000},'emp2':{'name':'jk','salary':6000}}
data['emp1']['salary']+=1000
del data['emp2']['name']
print(data)
# Out:
# {'emp1': {'name': 'ck', 'salary': 11000}, 'emp2': {'salary': 6000}}

# %%
d={}
d[True]='yes'
d[1]='one'
d[1.0]='float'
print(d)
# Out:
# {True: 'float'}

# %%
d={x:x*x for x in range(5)}
d.update({2:100})
print(d)
# Out:
# {0: 0, 1: 1, 2: 100, 3: 9, 4: 16}

# %%
d={'a':1,'b':2}
print('c' in d)
print(d.get('c'))
print(d.get('c',99))
# Out:
# False
# None
# 99

# %%
d={'outer':{'inner':10}}
d.setdefault('outer',{}).setdefault('inner',50)
d['outer']['inner']+=5
print(d)# setdefault (-it will set your data to default)
# Out:
# {'outer': {'inner': 15}}

# %%
d={'a':1,'b':2}
d2={k:v*10 for k,v in d.items()}
d['c']=3
d2.pop('a')
print(d)
print(d2)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'b': 20}

# %%
d={'a':1,'b':2}

for k in list(d.keys()):
    d[k*2]= d.pop(k)
print(d)
# Out:
# {'aa': 1, 'bb': 2}
