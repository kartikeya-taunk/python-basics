# %%
#list,tuple,dict
#list in detail
#list - orderd set of elements
#numbers,symbols,strings
list1=[]# empty list
list1
# Out:
# []

# %%
list2=[10,20,30,40]
list2
list3=[10,'$','a','20']
list3
# Out:
# [10, '$', 'a', '20']

# %%
type(list3)
# Out:
# list

# %%
#how to access the element from the list
num=[10,20,30,40]
num[0]
num[2]
num[-1]
num[-2]
# Out:
# 30

# %%
#list slicing
num[0:3] #2 elements #0,1,2,(0 excluded)
num[-1:-3:-1]# num[start:stop:step], it takes 1 on step as default
num[:]
num.append([50,60])
num
# Out:
# [10, 20, 30, 40, [50, 60], [50, 60], [50, 60], [50, 60], [50, 60], [50, 60]]

# %%
#list modify
list1=[10,20,30,40]
list1
list1[0]=100
list1
# Out:
# [100, 20, 30, 40]

# %%
#add elements
num=[1,2,3,4]
num.append(5)#add at the last of the list
num
# Out:
# [1, 2, 3, 4, 5]

# %%
#extend
num.extend([2,3,4])
num
# Out:
# [1, 2, 3, 4, 5, 2, 3, 4]

# %%
#insert (it add the element at any place acc to the given index)
num.insert(6,2)#(index,value)
num
# Out:
# [1, 2, 3, 4, 4, 5, 2, 2, 2, 3, 4, 22, 22]

# %%
#removing elements
num.remove(5)#it will remove the first occurance of given element
num
# Out:
# [1, 2, 3, 4, 4, 2, 2, 2, 3, 4, 22, 22]

# %%
#pop()
num.pop()#it will remove the element from the last of the list
num
num.pop(3)#it will remove the index value element
num
# Out:
# [1, 2, 3, 4, 2, 2, 2, 3, 4]

# %%
# looping in list
for i in list1:
    print(i,end=' ')
# Out:
# 100 20 30 40

# %%
for i in range(len(num)):
    print(num[i])
# Out:
# 1
# 2
# 3
# 4
# 2
# 2
# 2
# 3
# 4

# %%
# list comphrendion
sqrt=[i**2 for i in range(4)]
sqrt
# Out:
# [0, 1, 4, 9]

# %%
even_number=[x for x in range (10) if x%2==0]
even_number
# Out:
# [0, 2, 4, 6, 8]

# %%
num=[1,-5,24,9,0]
num.sort()
num
# Out:
# [-5, 0, 1, 9, 24]

# %%
sorted(num)
# Out:
# [-5, 0, 1, 9, 24]

# %%
sorted(num, reverse=True)
# Out:
# [24, 9, 1, 0, -5]

# %%
a=num.reverse()
a
num
a

# %%
num.count(24)
# Out:
# 1

# %%
num.index(-5)
num
num.index(1)
# Out:
# 2

# %%
l1=num
l1
num
num=l1.copy()
# Out:
# [-5, 0, 1, 9, 24]

# %%
l2=[[10,20],[40,50],[60,70]]
l2[0][1]
# Out:
# 20

# %%
a=[1,2,3]
b=a.copy()
b.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
a=[[1,2],[3,4]]
b=a.copy()
b[0][0]=99
print(a)
print(b)
# Out:
# [[99, 2], [3, 4]]
# [[99, 2], [3, 4]]

# %%
a=[1,2,3,4]
print(a[1:3])
print(a[-3:-1])
# Out:
# [2, 3]
# [2, 3]

# %%
a=[1,2,3]
a+=[4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=[1,2,3]
print([a]*3)
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a=[[]]*3
a[0].append(1)
a
# Out:
# [[1], [1], [1]]

# %%
a=[1,2,3]
print(a[::-1])
# Out:
# [3, 2, 1]

# %%
a=[10,20,30]
print(a.pop())
print(a)
# Out:
# 30
# [10, 20]

# %%
print([x*x for x in range(5)])
# Out:
# [0, 1, 4, 9, 16]

# %%
print([x for x in range (10) if x%3==0])
# Out:
# [0, 3, 6, 9]

# %%
a=[1,2,3]
print([a.append(x) for x in range (3)])
print(a)
# Out:
# [None, None, None]
# [1, 2, 3, 0, 1, 2]

# %%
print([[i]*3 for i in range(3)])
# Out:
# [[0, 0, 0], [1, 1, 1], [2, 2, 2]]

# %%
x=5
print([x for x in range(3)])
print(x)
# Out:
# [0, 1, 2]
# 5

# %%
print([lambda x: x*i for i in range (3)])
# Out:
# [<function <lambda> at 0x0000022F20790AE0>, <function <lambda> at 0x0000022F20790D60>, <function <lambda> at 0x0000022F20791EE0>]
